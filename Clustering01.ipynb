# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from sklearn.cluster import KMeans

# %% [markdown]
# # Exploratory data Analysis

# %%
Air_data=pd.read_csv("EastWestAirlines.csv")

# %%
Air_data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
#custom defind function for normalization
def norm_func(i):
    x=(i-i.min())/(i.max()-i.min())
    return (x)

# %%
def_norm=norm_func(Air_data.iloc[:,1:])
def_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# defind the min max 
from sklearn.preprocessing import MinMaxScaler
trans=MinMaxScaler()
data=pd.DataFrame(trans.fit_transform(Air_data))
data
# Out:
#             0         1    2     3    4    5         6         7         8   \
# 0     0.000000  0.016508  0.0  0.00  0.0  0.0  0.000660  0.011628  0.000000
# 1     0.000249  0.011288  0.0  0.00  0.0  0.0  0.000815  0.023256  0.000000
# 2     0.000498  0.024257  0.0  0.00  0.0  0.0  0.015636  0.046512  0.000000
# 3     0.000746  0.008667  0.0  0.00  0.0  0.0  0.001896  0.011628  0.000000
# 4     0.000995  0.057338  0.0  0.75  0.0  0.0  0.164211  0.302326  0.067398
# ...        ...       ...  ...   ...  ...  ...       ...       ...       ...
# 3994  0.999005  0.010837  0.0  0.00  0.0  0.0  0.032330  0.046512  0.006490
# 3995  0.999254  0.037766  0.0  0.00  0.0  0.0  0.003720  0.058140  0.000000
# 3996  0.999502  0.043169  0.0  0.50  0.0  0.0  0.096505  0.093023  0.000000
# 3997  0.999751  0.032202  0.0  0.00  0.0  0.0  0.001896  0.011628  0.016225
# 3998  1.000000  0.001769  0.0  0.00  0.0  0.0  0.000000  0.000000  0.000000
#
#             9         10   11
# ...

# %%
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch #for creating hierachical clustering

# %%
z=linkage(def_norm,method="complete",metric="euclidean")
plt.figure(figsize=(15,5))
plt.title("Hierachical clustering dendrogram")
plt.xlabel("Index")
plt.ylabel("Distance")
sch.dendrogram(
          z,
)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering # Agglomerativeclustering is  another name of hierachical clustering
h_complete=AgglomerativeClustering(n_clusters=5,linkage='complete',affinity='euclidean').fit(def_norm)
cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
Air_data['clust']=cluster_labels
Air_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Air_data.iloc[:,1:].groupby(Air_data.clust).mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clust
# 0       59968.433667   88.883768   1.712224   1.000401   1.011222
# 1      157084.578462  208.673846   4.661538   1.000000   1.061538
# 2       80173.963287  248.550699   2.104895   1.009615   1.000874
# 3      131999.500000  347.000000   2.500000   1.000000   1.000000
# 4       45515.064516   32.258065   1.000000   2.483871   1.000000
#
#         Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clust
# 0      10271.530261     9.105812         227.797194         0.656112
# 1      70477.086154    23.249231        1019.433846         3.196923
# 2      16882.864510    13.412587         739.958916         2.236888
# 3      65634.250000    69.250000       19960.000000        49.250000
# 4      14618.870968    16.129032         443.225806         1.967742
#
#        Days_since_enroll    Award?  clust
# clust
# 0            3825.392786  0.000802    0.0
# 1            5770.572308  1.000000    1.0
# ...

# %%
#same approach i can do with standardzing my data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
Air_data2=pd.DataFrame(scaler.fit_transform(Air_data))
Air_data2
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.735125 -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786
# 1    -1.734263 -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088
# 2    -1.733402 -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253
# 3    -1.732540 -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 4    -1.731679  0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994  1.725097 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960
# 3995  1.725958 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367
# 3996  1.726820 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804
# 3997  1.727682 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 3998  1.728543 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992
#
#             7         8         9         10        11        12
# ...

# %%
z=linkage(Air_data2,method="complete",metric="euclidean")
plt.figure(figsize=(15,5))
plt.title("Hierachical clustering dendrogram")
plt.xlabel("Index")
plt.ylabel("Distance")
sch.dendrogram(
          z,
)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
h_complete= AgglomerativeClustering(n_clusters=5,linkage='complete',affinity='euclidean').fit(Air_data2)
cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
Air_data2['clust']=cluster_labels
Air_data2
# Out:
#              0         1         2         3         4         5         6  \
# 0    -1.735125 -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786
# 1    -1.734263 -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088
# 2    -1.733402 -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253
# 3    -1.732540 -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 4    -1.731679  0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994  1.725097 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960
# 3995  1.725958 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367
# 3996  1.726820 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804
# 3997  1.727682 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 3998  1.728543 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992
#
# ...

# %%
data=Air_data2[(Air_data2.clust==3)].T
data
# Out:
#             2015       3583
# 0       0.014803   1.370976
# 1      -0.202151   0.858575
# 2       0.961630   0.460058
# 3       1.409471  -0.769578
# 4      -0.098242  -0.098242
# 5      -0.062767  -0.062767
# 6       2.631741   2.269723
# 7       5.560790   7.747696
# 8      15.456727  21.683004
# 9      11.502736  13.612053
# 10     -0.139262  -1.329648
# 11      1.303918   1.303918
# 12      2.456799   2.456799
# clust   3.000000   3.000000

# %% [markdown]
# # K_Mean Clustering

# %%
from sklearn.cluster import KMeans
fig = plt.figure(figsize=(10, 8))
WCSS = [] #within clusters sum of square
for i in range(1, 11):
    clf = KMeans(n_clusters=i)
    clf.fit(def_norm)
    WCSS.append(clf.inertia_) # inertia is another name for WCSS
plt.plot(range(1, 11), WCSS,"o-r")
plt.title('The Elbow Method')
plt.ylabel('WCSS')
plt.xlabel('Number of Clusters')
plt.show()

# %%
clf=KMeans(n_clusters=5)
y_KMeans=clf.fit_predict(def_norm)

# %%
y_KMeans
# Out:
# array([3, 3, 3, ..., 4, 0, 0])

# %%
clf.cluster_centers_ ## 11 values becz columns have 11 values
# Out:
# array([[ 1.94137515e-02,  8.44382696e-03,  1.76841085e-02,
#          8.23643411e-03,  1.69573643e-03,  1.23045313e-02,
#          7.17842978e-02,  6.90692719e-03,  1.13902296e-02,
#          2.39980966e-01, -4.99600361e-16],
#        [ 4.89953609e-02,  2.60542873e-02,  3.90044577e-02,
#          1.63447251e-02,  2.22882615e-03,  3.35642727e-02,
#          1.21825219e-01,  3.34267751e-02,  5.94073285e-02,
#          5.22892182e-01,  1.00000000e+00],
#        [ 6.93891884e-02,  6.59020789e-03,  6.46035599e-01,
#          8.09061489e-04,  5.66343042e-03,  1.19022293e-01,
#          2.00383834e-01,  7.27197078e-03,  1.18458814e-02,
#          5.32620376e-01,  5.71764858e-15],
#        [ 2.92823328e-02,  8.06451613e-03,  3.05299539e-02,
#          9.79262673e-03,  2.88018433e-04,  1.31485480e-02,
#          8.03906334e-02,  7.91232441e-03,  1.37379358e-02,
#          6.71078504e-01,  2.22044605e-15],
#        [ 6.35352962e-02,  1.77912301e-02,  7.28960396e-01,
# ...

# %%
clf.inertia_
# Out:
# 348.9433217254137

# %%
md=pd.Series(y_KMeans)
def_norm['clust']=md
def_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
def_norm.iloc[:,1:11].groupby(def_norm.clust).mean()
# Out:
#        Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# clust
# 0        0.008444   0.017684   0.008236   0.001696     0.012305     0.071784
# 1        0.026054   0.039004   0.016345   0.002229     0.033564     0.121825
# 2        0.006590   0.646036   0.000809   0.005663     0.119022     0.200384
# 3        0.008065   0.030530   0.009793   0.000288     0.013149     0.080391
# 4        0.017791   0.728960   0.000619   0.006498     0.172970     0.234904
#
#        Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# clust
# 0               0.006907         0.011390           0.239981     0.0
# 1               0.033427         0.059407           0.522892     1.0
# 2               0.007272         0.011846           0.532620     0.0
# 3               0.007912         0.013738           0.671079     0.0
# 4               0.023160         0.040421           0.586139     1.0

# %%
plt.rcParams["figure.figsize"]=(20,8)
df0=def_norm[def_norm.clust==0]
df1=def_norm[def_norm.clust==1]
df2=def_norm[def_norm.clust==2]
df3=def_norm[def_norm.clust==3]
plt.scatter(df0.Bonus_miles,df0.Qual_miles,s=50,color="green")
plt.scatter(df1.Bonus_miles,df1.Qual_miles,s=50,color="red")
plt.scatter(df2.Bonus_miles,df2.Qual_miles,s=50,color="yellow")
plt.scatter(df3.Bonus_miles,df3.Qual_miles,s=50,color="black")
